# %%
#importing all libraries needed 

import numpy as np
import pandas as pd

# %%
#importing my dataset 
df = pd.read_csv("Installation_Note_April.csv")

#loading the fist 30 rows of the dataset 
df.head(30)
# Out:
#           ID  Docstatus Installation_Date  \
# 0   INST0139          1        2019-01-02
# 1   INST0140          1        2019-01-18
# 2   INST0148          1        2019-03-29
# 3   INST0116          1        2019-04-08
# 4   INST0124          1        2019-05-03
# 5   INST0118          1        2019-08-14
# 6   INST0001          1        2019-10-24
# 7   INST0132          1        2019-11-13
# 8   INST0119          1        2019-11-21
# 9   INST0002          1        2020-01-16
# 10  INST0003          1        2020-02-14
# 11  INST0003          1        2020-02-14
# 12  INST0004          1        2020-03-24
# 13  INST0005          1        2020-04-24
# 14  INST0150          1        2020-06-23
# 15  INST0006          1        2020-06-23
# 16  INST0007          1        2020-07-06
# 17  INST0008          1        2020-07-09
# 18  INST0009          1        2020-07-10
# 19  INST0131          1        2020-07-23
# 20  INST0012          1        2020-07-23
# 21  INST0010          1        2020-07-29
# 22  INST0011          1        2020-08-17
# 23  INST0013          0        2020-08-28
# 24  INST0014          1        2020-09-10
# 25  INST0072          1        2020-09-15
# 26  INST0015          1        2020-09-15
# 27  INST0016          1        2020-09-24
# 28  INST0017          1        2020-09-24
# 29  INST0018          1        2020-10-27
#
#                                     Customer                         Owner  \
# 0             Shai Osudoku District Hospital      patrina.otoo@dcllabx.com
# 1                         KWATIRE POLYCLINIC      patrina.otoo@dcllabx.com
# 2            Kintampo Health Research Centre      patrina.otoo@dcllabx.com
# 3                          The Bank Hospital      patrina.otoo@dcllabx.com
# 4        AngloGold Ashanti Health Foundation      patrina.otoo@dcllabx.com
# 5            Effia Nkwanta Regional Hospital      patrina.otoo@dcllabx.com
# 6                                Iran Clinic   ernest.boasiako@dcllabx.com
# 7                          Biriwa Polyclinic      patrina.otoo@dcllabx.com
# 8            Effia Nkwanta Regional Hospital      patrina.otoo@dcllabx.com
# 9                   Anthon Memorial Hospital  michael.frimpong@dcllabx.com
# 10                       University Hospital       elsie.kafui@dcllabx.com
# 11                       University Hospital       elsie.kafui@dcllabx.com
# 12                  Goaso Municipal Hospital       elsie.kafui@dcllabx.com
# 13                           Police Hospital       elsie.kafui@dcllabx.com
# 14                      St. Dominic Hospital      patrina.otoo@dcllabx.com
# 15                      St. Dominic Hospital       elsie.kafui@dcllabx.com
# 16                       University of Ghana       elsie.kafui@dcllabx.com
# 17                           Police Hospital       elsie.kafui@dcllabx.com
# 18                Shukura Community Hospital       elsie.kafui@dcllabx.com
# 19              Takoradi (European) Hospital      patrina.otoo@dcllabx.com
# 20              Takoradi (European) Hospital        kwame.baah@dcllabx.com
# 21                            Rahma Hospital       elsie.kafui@dcllabx.com
# 22                       University of Ghana       elsie.kafui@dcllabx.com
# 23                            Trust Hospital  michael.frimpong@dcllabx.com
# 24           Agona Swedru Municipal Hospital        kwame.baah@dcllabx.com
# 25    Ghana Infectious Disease Centre (GIDC)       elsie.kafui@dcllabx.com
# 26         GA-EAST Infectious Disease Center       elsie.kafui@dcllabx.com
# 27                            Trust Hospital  michael.frimpong@dcllabx.com
# 28           Agona Swedru Municipal Hospital       elsie.kafui@dcllabx.com
# 29  University of Health and Allied Sciences       elsie.kafui@dcllabx.com
#
#        Status                                            Remarks  \
# 0   Submitted          Installation and user training completed.
# 1   Submitted  installation and user training completed\n\nSe...
# 2   Submitted                    serial number, BKQ 5011 1812508
# 3   Submitted                            serial number'; 18-9613
# 4   Submitted  serial number ; \n\nInstallation and user trai...
# 5   Submitted  serial number; 18-9625\n\nInstallation and use...
# 6   Submitted  DONATION OF XPERT HIV-1 Qual to AURUM PROJECT-...
# 7   Submitted  serial number - 642826\n\ninstallation and use...
# 8   Submitted  serial number; CT-ISE-auto-3214\n\nInstallatio...
# 9   Submitted                        Installation was successful
# 10  Submitted                        Installation was successful
# 11  Submitted                        Installation was successful
# 12  Submitted      Installation and end user training of A380 \n
# 13  Submitted  -Installation and User Training of Selectra Pr...
# 14  Submitted                              Serial number 05-4892
# 15  Submitted  Installation and End-User training of NF 800 C...
# 16  Submitted                        Installation was successful
# 17  Submitted                           Installation of ISE unit
# 18  Submitted                        Installation was successful
# 19  Submitted  serial number; 20-9627\n\n\nInstallation and u...
# 20  Submitted          Installation and user training successful
# 21  Submitted                     Installation and User training
# 22  Submitted  Two medical refrigerators were successfully in...
# 23      Draft                        Installation was successful
# 24  Submitted  Installation of pro s with serial number 20-96...
# 25  Submitted    Installation of 2 Medica EasyBloodgas Analyzers
# 26  Submitted                        Installation was successful
# 27  Submitted                        Installation was successful
# 28  Submitted  Installation and user training of Smartlyte pl...
# 29  Submitted                        Installation was successful
#
#                Creation                                       Item_Code  \
# 0   2023-05-04 10:45:26                                            ND 8
# 1   2023-05-04 10:50:53                                            A380
# 2    2023-05-12 9:57:26                                       BKQ-B50II
# 3   2023-04-28 10:53:18                                        6003 542
# 4   2023-04-28 12:59:01                                            AB 5
# 5   2023-04-28 12:10:40                                        6003-542
# 6   2019-10-24 11:23:40                                      HIV-1 Qual
# 7   2023-04-28 14:36:37                                            A380
# 8   2023-04-28 12:26:25  Convergys ISE comfort Electrolyte Analyzer M03
# 9   2020-01-21 16:34:16                     Micros Pink MC50 Microscope
# 10  2020-02-14 16:35:43                                             UPS
# 11  2020-02-14 16:35:43                                        23020003
# 12  2020-03-24 11:57:01                                            A380
# 13  2020-04-24 16:44:19                                        6003-543
# 14  2023-05-12 10:43:36                                          NF 800
# 15  2020-06-24 11:36:30                                          NF 800
# 16   2020-07-06 9:26:31                                 0-DD- SMARTLYTE
# 17  2020-07-09 10:40:22                                            S001
# 18  2020-07-10 16:09:35                                            A380
# 19  2023-04-28 14:31:26                                        6003 542
# 20   2020-08-19 8:59:54                                        6003-542
# 21   2020-07-29 9:25:23                                            A380
# 22  2020-08-17 17:12:48                            Medical Refrigerator
# 23  2020-08-28 10:37:06                                      BKM-P24III
# 24   2020-09-14 9:10:58                                        6003-543
# 25  2022-03-31 15:55:13                              Blood Gas Analyzer
# 26  2020-09-16 10:24:07                                      MEDICA2014
# 27  2020-09-24 10:02:08              Autoclave Sterilizer Machine (23L)
# 28  2020-09-24 10:12:20                              0-DD-SMARTLYTEPLUS
# 29   2020-10-27 7:31:09                                  rayto RT-2204C
#
#     Installed_Qty Acquisition_Type Equipment_Type Maintenance_Interval  \
# 0               1         Outright  Non- Analyzer            12 Months
# 1               1         Retrived       Analyzer            12 Months
# 2               1         Outright  Non- Analyzer            12 Months
# 3               1         Outright       Analyzer            12 Months
# 4               1         Outright  Non- Analyzer            12 Months
# 5               1         Outright       Analyzer            12 Months
# 6              20         Outright  Non- Analyzer            12 Months
# 7               1        Placement       Analyzer             6 Months
# 8               1        Placement       Analyzer             6 Months
# 9               1         Outright  Non- Analyzer            12 Months
# 10              1         Outright  Non- Analyzer            12 Months
# 11              1         Outright  Non- Analyzer            12 Months
# 12              1                #       Analyzer            12 Months
# 13              1         Outright       Analyzer            12 Months
# 14              1         Outright  Non- Analyzer            12 Months
# 15              1         Outright  Non- Analyzer            12 Months
# 16              1        Placement       Analyzer             6 Months
# 17              1        Placement       Analyzer             6 Months
# 18              1        Retrieved       Analyzer            12 Months
# 19              1                #       Analyzer            12 Months
# 20              1        Placement       Analyzer             6 Months
# 21              1        Placement       Analyzer             6 Months
# 22              2         Outright  Non- Analyzer            12 Months
# 23              1         Outright  Non- Analyzer            12 Months
# 24              1        Retrieved       Analyzer            12 Months
# 25              2         Outright       Analyzer            12 Months
# 26              2         Outright  Non- Analyzer            12 Months
# 27              1         Outright  Non- Analyzer            12 Months
# 28              1         Outright       Analyzer            12 Months
# 29              1         Outright       Analyzer            12 Months
#
#    Last_Date_Maintained
# 0            2019-01-02
# 1            2019-01-18
# 2            2019-03-29
# 3            2019-04-08
# 4            2019-05-03
# 5            2019-08-14
# 6            2019-10-24
# 7            2024-04-12
# 8            2023-07-21
# 9            2020-01-16
# 10           2020-02-14
# 11           2020-02-14
# 12           2020-03-24
# 13           2020-04-24
# 14           2020-06-23
# 15           2020-06-23
# 16           2020-07-06
# 17           2020-07-09
# 18           2020-07-10
# 19           2020-07-23
# 20           2020-07-23
# 21           2020-07-29
# 22           2020-08-17
# 23           2020-08-28
# 24           2020-09-10
# 25           2020-09-15
# 26           2020-09-15
# 27           2020-09-24
# 28           2020-09-24
# 29           2020-10-27

# %%
#Checking the summary of my dataset using the info method 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    145 non-null    object
#  1   Docstatus             145 non-null    int64
#  2   Installation_Date     145 non-null    object
#  3   Customer              145 non-null    object
#  4   Owner                 145 non-null    object
#  5   Status                145 non-null    object
#  6   Remarks               145 non-null    object
#  7   Creation              145 non-null    object
#  8   Item_Code             145 non-null    object
#  9   Installed_Qty         145 non-null    int64
#  10  Acquisition_Type      145 non-null    object
#  11  Equipment_Type        145 non-null    object
#  12  Maintenance_Interval  144 non-null    object
#  13  Last_Date_Maintained  145 non-null    object
# dtypes: int64(2), object(12)
# memory usage: 16.0+ KB

# %%
#Using describe to check basic numerical calculations 
df.describe()
# Out:
#         Docstatus  Installed_Qty
# count  145.000000     145.000000
# mean     1.000000       1.227586
# std      0.117851       1.614796
# min      0.000000       1.000000
# 25%      1.000000       1.000000
# 50%      1.000000       1.000000
# 75%      1.000000       1.000000
# max      2.000000      20.000000

# %%
df.columns
# Out:
# Index(['ID', 'Docstatus', 'Installation_Date', 'Customer', 'Owner', 'Status',
#        'Remarks', 'Creation', 'Item_Code', 'Installed_Qty', 'Acquisition_Type',
#        'Equipment_Type', 'Maintenance_Interval', 'Last_Date_Maintained'],
#       dtype='object')

# %%
#Checking a column of the dataset 
df[["Acquisition_Type"]]
# Out:
#     Acquisition_Type
# 0           Outright
# 1           Retrived
# 2           Outright
# 3           Outright
# 4           Outright
# ..               ...
# 140         Outright
# 141         Outright
# 142         Outright
# 143        Placement
# 144        Placement
#
# [145 rows x 1 columns]

# %%
df
# Out:
#            ID  Docstatus Installation_Date  \
# 0    INST0139          1        2019-01-02
# 1    INST0140          1        2019-01-18
# 2    INST0148          1        2019-03-29
# 3    INST0116          1        2019-04-08
# 4    INST0124          1        2019-05-03
# ..        ...        ...               ...
# 140  INST0162          1        2024-02-19
# 141  INST0163          1        2024-02-22
# 142  INST0164          1        2024-02-28
# 143  INST0166          1        2024-04-16
# 144  INST0165          1        2024-04-16
#
#                                 Customer                        Owner  \
# 0         Shai Osudoku District Hospital     patrina.otoo@dcllabx.com
# 1                     KWATIRE POLYCLINIC     patrina.otoo@dcllabx.com
# 2        Kintampo Health Research Centre     patrina.otoo@dcllabx.com
# 3                      The Bank Hospital     patrina.otoo@dcllabx.com
# 4    AngloGold Ashanti Health Foundation     patrina.otoo@dcllabx.com
# ..                                   ...                          ...
# 140    MDS-LANCET LABORATORIES GHANA LTD  kenneth.atakora@dcllabx.com
# 141                  University Hospital  kenneth.atakora@dcllabx.com
# 142         Cape Coast Teaching Hospital  ebenezer.dzidah@dcllabx.com
# 143                  University Hospital     cecil.ayeebo@dcllabx.com
# 144                  University Hospital     cecil.ayeebo@dcllabx.com
#
#         Status                                            Remarks  \
# 0    Submitted          Installation and user training completed.
# 1    Submitted  installation and user training completed\n\nSe...
# 2    Submitted                    serial number, BKQ 5011 1812508
# 3    Submitted                            serial number'; 18-9613
# 4    Submitted  serial number ; \n\nInstallation and user trai...
# ..         ...                                                ...
# 140  Submitted  The installation of 4  bench-top centrifuge of...
# 141  Submitted  NF 800 with serial number 06.5561 installation...
# 142  Submitted  Nuve ND 12 with serial number: 03.1803 was suc...
# 143  Submitted         SN#; K11052050030 at the main hospital lab
# 144  Submitted   installed at University of Ghana Hospital. \n...
#
#                 Creation  Item_Code  Installed_Qty Acquisition_Type  \
# 0    2023-05-04 10:45:26       ND 8              1         Outright
# 1    2023-05-04 10:50:53       A380              1         Retrived
# 2     2023-05-12 9:57:26  BKQ-B50II              1         Outright
# 3    2023-04-28 10:53:18   6003 542              1         Outright
# 4    2023-04-28 12:59:01       AB 5              1         Outright
# ..                   ...        ...            ...              ...
# 140   2024-02-19 9:17:58     NF 200              4         Outright
# 141  2024-02-22 17:42:40     NF 800              1         Outright
# 142  2024-03-01 10:30:58      ND 12              1         Outright
# 143  2024-04-17 14:08:25  ELite 580              1        Placement
# 144  2024-04-17 14:02:27  ELite 580              1        Placement
#
#     Equipment_Type Maintenance_Interval Last_Date_Maintained
# 0    Non- Analyzer            12 Months           2019-01-02
# 1         Analyzer            12 Months           2019-01-18
# 2    Non- Analyzer            12 Months           2019-03-29
# 3         Analyzer            12 Months           2019-04-08
# 4    Non- Analyzer            12 Months           2019-05-03
# ..             ...                  ...                  ...
# 140  Non- Analyzer            12 Months           2024-02-19
# 141  Non- Analyzer            12 Months           2024-02-22
# 142  Non- Analyzer            12 Months           2024-02-28
# 143       Analyzer             6 Months           2024-04-16
# 144       Analyzer             6 Months           2024-04-16
#
# [145 rows x 14 columns]

# %%
from datetime import datetime, timedelta
import pandas as pd

# Function to calculate maintenance due date for each row
def calculate_maintenance_due_date(row):
    installation_date = pd.to_datetime(row['Installation_Date'])
    equipment_type = row['Equipment_Type']
    acquisition_type = row['Acquisition_Type']
    last_maintenance_date = pd.to_datetime(row['Last_Date_Maintained'])
    maintenance_interval = row['Maintenance_Interval']

    # Check if maintenance interval is NaN
    if pd.isna(maintenance_interval):
        return pd.NaT, pd.NaT

    # Extract the numeric part from maintenance interval
    maintenance_interval = int(''.join(filter(str.isdigit, str(maintenance_interval))))

    # Calculate initial due date
    initial_due_date = installation_date + timedelta(days=maintenance_interval * 30)

    # If last maintenance date is available and valid, use it instead
    if pd.notnull(last_maintenance_date):
        last_due_date = last_maintenance_date + timedelta(days=maintenance_interval * 30)
        if last_due_date > initial_due_date:
            initial_due_date = last_due_date

    # Calculate maintenance due date for 2024
    maintenance_due_date_2024 = initial_due_date.replace(year=2024)

    return initial_due_date, maintenance_due_date_2024

# Read the CSV file
df = pd.read_csv('Installation_Note_April.csv')

# Apply the function to calculate maintenance due dates for 2024
df[['Initial_Due_Date', 'Maintenance_Due_Date_2024']] = df.apply(calculate_maintenance_due_date, axis=1, result_type='expand')

# Print the dataframe with selected columns
print(df[['Installation_Date', 'Customer', 'Item_Code', 'Equipment_Type', 'Acquisition_Type', 'Last_Date_Maintained', 'Initial_Due_Date', 'Maintenance_Due_Date_2024']])

# Save the dataframe to a CSV file
df.to_csv('maintenance_due_dates.csv', index=False)

print("\nDataFrame saved to maintenance_due_dates.csv")
# Out:
#     Installation_Date                             Customer  Item_Code  \
# 0          2019-01-02       Shai Osudoku District Hospital       ND 8
# 1          2019-01-18                   KWATIRE POLYCLINIC       A380
# 2          2019-03-29      Kintampo Health Research Centre  BKQ-B50II
# 3          2019-04-08                    The Bank Hospital   6003 542
# 4          2019-05-03  AngloGold Ashanti Health Foundation       AB 5
# ..                ...                                  ...        ...
# 140        2024-02-19    MDS-LANCET LABORATORIES GHANA LTD     NF 200
# 141        2024-02-22                  University Hospital     NF 800
# 142        2024-02-28         Cape Coast Teaching Hospital      ND 12
# 143        2024-04-16                  University Hospital  ELite 580
# 144        2024-04-16                  University Hospital  ELite 580
#
#     Equipment_Type Acquisition_Type Last_Date_Maintained Initial_Due_Date  \
# 0    Non- Analyzer         Outright           2019-01-02       2019-12-28
# 1         Analyzer         Retrived           2019-01-18       2020-01-13
# 2    Non- Analyzer         Outright           2019-03-29       2020-03-23
# 3         Analyzer         Outright           2019-04-08       2020-04-02
# 4    Non- Analyzer         Outright           2019-05-03       2020-04-27
# ..             ...              ...                  ...              ...
# 140  Non- Analyzer         Outright           2024-02-19       2025-02-13
# 141  Non- Analyzer         Outright           2024-02-22       2025-02-16
# 142  Non- Analyzer         Outright           2024-02-28       2025-02-22
# 143       Analyzer        Placement           2024-04-16       2024-10-13
# 144       Analyzer        Placement           2024-04-16       2024-10-13
#
#     Maintenance_Due_Date_2024
# 0                  2024-12-28
# 1                  2024-01-13
# 2                  2024-03-23
# 3                  2024-04-02
# 4                  2024-04-27
# ..                        ...
# 140                2024-02-13
# 141                2024-02-16
# 142                2024-02-22
# 143                2024-10-13
# 144                2024-10-13
#
# [145 rows x 8 columns]
#
# DataFrame saved to maintenance_due_dates.csv

# %%
# Filter the DataFrame to include only the row with Customer name "Adidome Government Hospital"
adidome_hospital_row = df[df['Customer'] == 'Adidome Government Hospital']

# Print the filtered row
print(adidome_hospital_row)
# Out:
#           ID  Docstatus Installation_Date                     Customer  \
# 52  INST0036          1        2021-05-19  Adidome Government Hospital
#
#                      Owner     Status  \
# 52  kwame.baah@dcllabx.com  Submitted
#
#                                       Remarks            Creation Item_Code  \
# 52  Installation and User training successful  2021-05-24 9:33:32      S001
#
#     Installed_Qty Acquisition_Type Equipment_Type Maintenance_Interval  \
# 52              1        Placement       Analyzer             6 Months
#
#    Last_Date_Maintained Initial_Due_Date Maintenance_Due_Date_2024
# 52           2023-06-19       2023-12-16                2024-12-16

# %%
import matplotlib.pyplot as plt

# Assuming df is your DataFrame containing installation dates
plt.figure(figsize=(10, 8))
plt.plot(df['Installation_Date'], marker='o')
plt.title('Equipment Installation Trends')
plt.xlabel('Date')
plt.ylabel('Number of Installations')
plt.grid(True)
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(8, 8))
sns.countplot(data=df, x='Equipment_Type')
plt.title('Equipment Type Distribution')
plt.xlabel('Equipment Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, y='Acquisition_Type')
plt.title('Acquisition Type Distribution')
plt.xlabel('Count')
plt.ylabel('Acquisition Type')
plt.show()

# %%
import matplotlib.pyplot as plt

# Convert 'Maintenance_Interval' column to numeric format
df['Maintenance_Interval'] = df['Maintenance_Interval'].str.extract('(\d+)').astype(float)

# Plot histogram
plt.figure(figsize=(8, 6))
plt.hist(df['Maintenance_Interval'].dropna(), bins=10)
plt.title('Maintenance Interval Analysis')
plt.xlabel('Maintenance Interval (months)')
plt.ylabel('Frequency')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(df['Maintenance_Due_Date_2024'], marker='o')
plt.title('Maintenance Due Dates Distribution')
plt.xlabel('Date')
plt.ylabel('Maintenance Due Date')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Filter the DataFrame for placement equipment
placement_df = df[df['Acquisition_Type'] == 'Placement']

# Plot the maintenance due dates for placement equipment
plt.figure(figsize=(10, 6))
plt.plot(placement_df['Maintenance_Due_Date_2024'], marker='o', linestyle='', color='b')
plt.title('Maintenance Due Dates for Placement Equipment')
plt.xlabel('Date')
plt.ylabel('Maintenance Due Date')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# Filter the DataFrame for placement equipment
placement_maintenance_df = df[df['Acquisition_Type'] == 'Placement'][['Customer', 'Item_Code', 'Equipment_Type', 'Acquisition_Type', 'Maintenance_Due_Date_2024']]

# Merge with the initial due date column
placement_maintenance_df = placement_maintenance_df.merge(df[['Item_Code', 'Initial_Due_Date']], on='Item_Code', how='left')

print(placement_maintenance_df)
# Out:
#                Customer  Item_Code Equipment_Type Acquisition_Type  \
# 0     Biriwa Polyclinic       A380       Analyzer        Placement
# 1     Biriwa Polyclinic       A380       Analyzer        Placement
# 2     Biriwa Polyclinic       A380       Analyzer        Placement
# 3     Biriwa Polyclinic       A380       Analyzer        Placement
# 4     Biriwa Polyclinic       A380       Analyzer        Placement
# ..                  ...        ...            ...              ...
# 87  University Hospital  ELite 580       Analyzer        Placement
# 88  University Hospital  ELite 580       Analyzer        Placement
# 89  University Hospital  ELite 580       Analyzer        Placement
# 90  University Hospital  ELite 580       Analyzer        Placement
# 91  University Hospital  ELite 580       Analyzer        Placement
#
#    Maintenance_Due_Date_2024 Initial_Due_Date
# 0                 2024-10-09       2020-01-13
# 1                 2024-10-09       2024-10-09
# 2                 2024-10-09       2021-03-19
# 3                 2024-10-09       2021-07-05
# 4                 2024-10-09       2021-01-25
# ..                       ...              ...
# 87                2024-10-13       2024-10-13
# 88                2024-10-13       2023-02-21
# 89                2024-10-13       2023-08-02
# 90                2024-10-13       2024-10-13
# 91                2024-10-13       2024-10-13
#
# [92 rows x 6 columns]

# %%
# Filter the DataFrame for placement equipment
placement_maintenance_df = df[df['Acquisition_Type'] == 'Placement'][['Customer', 'Item_Code', 'Equipment_Type', 'Acquisition_Type', 'Initial_Due_Date', 'Maintenance_Due_Date_2024']]

# Save the filtered DataFrame to a CSV file
placement_maintenance_df.to_csv('placement_maintenance_due_dates.csv', index=False)
